# %% [markdown]
# SignUp the www.kaggle.com and follow the below instructions.

# %% [markdown]
# Download the DataSet from the website and upload in the Drive.
#
# Reference: https://www.kaggle.com/shubh0799/churn-modelling

# %% [markdown]
# # **Mount The Drive as per the below command.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# # **Pandas**
# Pandas is fast, powerful, flexible and easy to use open source data analysis and manipulation tool.
#
# Pandas is a Python library.
#
# Pandas is used to analyze data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Pandas Series**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Pandas DataFrames**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#pip install pandas # If you dont have pandas in your IDLE. install pandas by the given command

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/SEMESTER 5/DATA SCIENCE (By SS)/Churn_Modelling.csv')
df
#df = pd.read_excel('xyz.xlsx', sheet_name = 'Page 1')
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.iloc[:3]

#loc # Lable based indexing
#iloc str int position based indexing
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited  New Balance Random Column
# 0        101348.88       1      1000.00      Good Day
# 1        112542.58       0     84807.86      Good Day
# 2        113931.57       1    160660.80      Good Day

# %%
  df.head()  # First 5 rows will be printed as default
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.head(15)  # First 10 rows will be printed as manual
# Out:
#     RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602  Hargrave          619    France  Female   42
# 1           2    15647311      Hill          608     Spain  Female   41
# 2           3    15619304      Onio          502    France  Female   42
# 3           4    15701354      Boni          699    France  Female   39
# 4           5    15737888  Mitchell          850     Spain  Female   43
# 5           6    15574012       Chu          645     Spain    Male   44
# 6           7    15592531  Bartlett          822    France    Male   50
# 7           8    15656148    Obinna          376   Germany  Female   29
# 8           9    15792365        He          501    France    Male   44
# 9          10    15592389        H?          684    France    Male   27
# 10         11    15767821    Bearce          528    France    Male   31
# 11         12    15737173   Andrews          497     Spain    Male   24
# ...

# %%
df.head(30)
# Out:
#     RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602    Hargrave          619    France  Female   42
# 1           2    15647311        Hill          608     Spain  Female   41
# 2           3    15619304        Onio          502    France  Female   42
# 3           4    15701354        Boni          699    France  Female   39
# 4           5    15737888    Mitchell          850     Spain  Female   43
# 5           6    15574012         Chu          645     Spain    Male   44
# 6           7    15592531    Bartlett          822    France    Male   50
# 7           8    15656148      Obinna          376   Germany  Female   29
# 8           9    15792365          He          501    France    Male   44
# 9          10    15592389          H?          684    France    Male   27
# 10         11    15767821      Bearce          528    France    Male   31
# 11         12    15737173     Andrews          497     Spain    Male   24
# ...

# %%
df.tail() # last 5 rows will be printed as default
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.tail(20) # last 10 rows will be printed as default
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 9980       9981    15719276            T'ao          741     Spain    Male
# 9981       9982    15672754        Burbidge          498   Germany    Male
# 9982       9983    15768163         Griffin          655   Germany  Female
# 9983       9984    15656710           Cocci          613    France    Male
# 9984       9985    15696175  Echezonachukwu          602   Germany    Male
# 9985       9986    15586914          Nepean          659    France    Male
# 9986       9987    15581736        Bartlett          673   Germany    Male
# 9987       9988    15588839         Mancini          606     Spain    Male
# 9988       9989    15589329         Pirozzi          775    France    Male
# 9989       9990    15605622        McMillan          841     Spain    Male
# 9990       9991    15798964      Nkemakonam          714   Germany    Male
# ...

# %%
df.tail(10000)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.info() # Entire info about the DataFrames
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Describe the statistical information of the numerical columns
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
# Prints all the columns of the dataframe

df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df['Age']
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
# Transpose

df.T
# Out:
#                       0          1          2         3          4     \
# RowNumber                1          2          3         4          5
# CustomerId        15634602   15647311   15619304  15701354   15737888
# Surname           Hargrave       Hill       Onio      Boni   Mitchell
# CreditScore            619        608        502       699        850
# Geography           France      Spain     France    France      Spain
# Gender              Female     Female     Female    Female     Female
# Age                     42         41         42        39         43
# Tenure                   2          1          8         1          2
# Balance                0.0   83807.86   159660.8       0.0  125510.82
# NumOfProducts            1          1          3         2          1
# HasCrCard                1          0          1         0          1
# IsActiveMember           1          1          0         0          1
# ...

# %%
# How to access your rows

df[1:1000]
# Out:
#      RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 1            2    15647311        Hill          608     Spain  Female   41
# 2            3    15619304        Onio          502    France  Female   42
# 3            4    15701354        Boni          699    France  Female   39
# 4            5    15737888    Mitchell          850     Spain  Female   43
# 5            6    15574012         Chu          645     Spain    Male   44
# ..         ...         ...         ...          ...       ...     ...  ...
# 995        996    15810218         Sun          610     Spain    Male   29
# 996        997    15645621      Hunter          811     Spain    Male   44
# 997        998    15608114     Manfrin          587     Spain    Male   62
# 998        999    15659557  Artamonova          811   Germany  Female   28
# 999       1000    15787772      Hansen          759    France  Female   38
#
#      Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.Age
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
#Sort your dataframe based on Age

df.sort_values('Age')
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
# ...

# %%
#Sort your dataframe based on Tenure

df.sort_values('Tenure')
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 5887       5888    15691287           Ford          675   Germany  Female
# 6709       6710    15587647         Browne          850   Germany  Female
# 6706       6707    15732235     Kuykendall          662    France    Male
# 9205       9206    15758750  Iweobiegbunam          564    France    Male
# 9206       9207    15611767            Mai          624   Germany  Female
# ...         ...         ...            ...          ...       ...     ...
# 621         622    15603134            Pai          656     Spain  Female
# 2007       2008    15727384    Chukwuemeka          705   Germany  Female
# 245         246    15797219     Ifesinachi          635    France  Female
# 3419       3420    15684103         Mellor          674    France  Female
# 4617       4618    15799932  Iweobiegbunam          812    France    Male
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['Balance']
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df.Balance  #Input Balance kind of string will not work here
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df['New Balance'] = df['Balance'] + 1000
#df.head(5)
#df['Balance']
df['New Balance']
# Out:
# 0         1000.00
# 1        84807.86
# 2       160660.80
# 3         1000.00
# 4       126510.82
#           ...
# 9995      1000.00
# 9996     58369.61
# 9997      1000.00
# 9998     76075.31
# 9999    131142.79
# Name: New Balance, Length: 10000, dtype: float64

# %%
df['Random Column'] = 'Good Day' #wil create new column call random column
#df.head(5)
df['Random Column']
# Out:
# 0       Good Day
# 1       Good Day
# 2       Good Day
# 3       Good Day
# 4       Good Day
#           ...
# 9995    Good Day
# 9996    Good Day
# 9997    Good Day
# 9998    Good Day
# 9999    Good Day
# Name: Random Column, Length: 10000, dtype: object

# %%
# How to access your rows

df[10:12]
df[11:21:2]     #like strat stop step
# Out:
#     RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 11         12    15737173    Andrews          497     Spain    Male   24
# 13         14    15691483       Chin          549    France  Female   25
# 15         16    15643966    Goforth          616   Germany    Male   45
# 17         18    15788218  Henderson          549     Spain  Female   24
# 19         20    15568982        Hao          726    France  Female   24
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 11       3       0.00              2          1               0
# 13       5       0.00              2          0               0
# 15       3  143129.41              2          0               1
# 17       9       0.00              2          1               1
# 19       6       0.00              2          1               1
#
#     EstimatedSalary  Exited
# 11         76390.01       0
# 13        190857.79       0
# 15         64327.26       0
# ...

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## **Conditional Statements**

# %%
new_df = df[df.Age > 50]

# %%
new_df
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 16           17    15737452        Romeo          653   Germany    Male   58
# 41           42    15738148       Clarke          465    France  Female   51
# 42           43    15687946      Osborne          556    France  Female   61
# 44           45    15684171      Bianchi          660     Spain  Female   61
# 58           59    15623944        T'ien          511     Spain  Female   66
# ...         ...         ...          ...          ...       ...     ...  ...
# 9936       9937    15653037        Parks          609    France    Male   77
# 9939       9940    15808971       Lajoie          693     Spain  Female   57
# 9948       9949    15735078    Onwughara          724   Germany  Female   53
# 9979       9980    15692664       Diribe          677    France  Female   58
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
#
# ...

# %%
len(df)
# Out:
# 10000

# %%
len(new_df)
# Out:
# 1261

# %%
new_df_Age_greater_50 = df[df.Age > 50]

# %%
new_df_Age_greater_50.head(5)
# Out:
#     RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 16         17    15737452    Romeo          653   Germany    Male   58
# 41         42    15738148   Clarke          465    France  Female   51
# 42         43    15687946  Osborne          556    France  Female   61
# 44         45    15684171  Bianchi          660     Spain  Female   61
# 58         59    15623944    T'ien          511     Spain  Female   66
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 16       1  132602.88              1          1               0
# 41       8  122522.32              1          0               0
# 42       2  117419.35              1          1               1
# 44       5  155931.11              1          1               1
# 58       4       0.00              1          1               0
#
#     EstimatedSalary  Exited
# 16          5097.67       1
# 41        181297.65       1
# 42         94153.83       0
# 44        158338.39       0
# ...

# %% [markdown]
# ## **Treat Null Values: fillna/dropna**

# %%
df.Age.mean()

# %%
df['Age'].fillna(df.Age.mean())

# %%
df['Age'].fillna(10)

# %%
new_df.head(5)

# %% [markdown]
# ## **Column Removal / Dropping**

# %%
new_df.pop('RowNumber') # Delete the RowNumber

# %%
new_df

# %%
new_df_Age_greater_50_1 = new_df_Age_greater_50.drop('RowNumber', axis=1) # Delete the RowNumber

# %%
new_df_Age_greater_50_1.head(5)

# %%
new_df_Age_greater_50.head(5)

# %% [markdown]
# ## **Apply Numpy Operation**

# %%
df['Balance']

# %%
df['Balance']

# %%
df['Balance'].apply(np.sqrt)

# %%
df['SqRoot_Balance'] = df['Balance'].apply(np.sqrt) # Apply and to store in a new column

# %%
#Drops all the null values in Age column

df['Age'].dropna()

# %%
df.dropna()

# %% [markdown]
# # **Concat & Merging**

# %%
import pandas as pd

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                  index=[0,1,2,3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                  index=[4,5,6,7])

# %%
#frames = [df1,df2]

# %%
result = pd.concat([df1, df2])

# %%
df1

# %%
df2

# %%
result

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']}, )


df2 = pd.DataFrame({'E': ['A4', 'A5', 'A6', 'A7'],
                    'F': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C0', 'C3', 'C6', 'C7'],
                    'G': ['D4', 'D5', 'D6', 'D7']}, )


merge_df = pd.merge(df1, df2, on='C', how='outer')

# %%
merge_df

# %% [markdown]
# # **loc vs iloc**

# %% [markdown]
# The main distinction between the two methods is:
#
# loc gets rows (and/or columns) with particular
# labels.
#
# iloc gets rows (and/or columns) at integer locations.

# %%
import pandas as pd
s = pd.Series(list("abcdef"), index=[49, 48, 47, 0, 1, 2])
s

# %%
s.loc[0]    # value at index label 0

# %%
s.iloc[0]   # value at index location 0

# %%
s.loc[0:1]  # rows at index labels between 0 and 1 (inclusive)

# %%
s.iloc[0:1] # rows at index location between 0 and 1 (exclusive)

# %% [markdown]
# # **What if you sort the Series**

# %%
s = s.sort_index()

# %%
s

# %%
s.iloc[0]

# %%
s.loc[0]    # value at index label 0

# %%
s.iloc[0]   # value at index location 0

# %%
s.loc[0:1]  # rows at index labels between 0 and 1 (inclusive)

# %%
s.iloc[0:1] # rows at index location between 0 and 1 (exclusive)

# %%
print("heloo")
# Out:
# heloo

# %%
matplotib.org

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
values=[1,5,8,9,2,0,3,10,4,7]
plt.plot(range(1,11),values)
plt.show()
